# %% [markdown]
# <h2>ch5 머신러닝</h2>

# %% [markdown]
# <머신러닝 시작하기에 앞서 >

# %% [markdown]
# 머신러닝은 지도학습(supervised감독) 과 비지도 학습(unsupervised)의 두가지 주요 유형
#
# 1)지도학습
# feature  입력데이터
# label    긍정/부정
#
# 지도학습의 모델을 이용해 알려지지 않은 새 데이터에 레이블을 적용할 수 있다.이것은 다시 분류와 회귀로 나뉜다.
# 2)비지도 학습
# feature 모델링, 데이터세트가 스스로 말하게 하는 것
# 군집화, 차원축소와 같은 작업

# %% [markdown]
# <h3>지도학습-분류</h3>

# %% [markdown]
# ![image.png](attachment:bb10d9cb-8568-4e98-8476-7153df4cb210.png)

# %% [markdown]
# y=ax+b가 우리가 찾으려는 규칙(모델)이라고 하자.
# 학습(러닝)을 통해 a,b(모델모수)를 찾아햐 한다. a, b를 가중치라고 한다.
#
# 3)예측
# 모델이 학습됐으니(가중치 a,b를 찾았으므로 y=ax+b 규칙이 완성된다.) 이제 그것을 레이블이 없는 새 데이터에 일반화 할 수 있다.
# 즉, 새로운 데이터 집합을 가져와 그 집합에 이 모델의 선을 그리고, 이 모델을 기반으로 새 점에 레이블을 할당할 수 있다.

# %% [markdown]
# Some important classification algorithms that we will discuss in more detail are Gaussian naive Bayes (see [In Depth: Naive Bayes Classification](05.05-Naive-Bayes.ipynb)), support vector machines (see [In-Depth: Support Vector Machines](05.07-Support-Vector-Machines.ipynb)), and random forest classification (see [In-Depth: Decision Trees and Random Forests](05.08-Random-Forests.ipynb)).

# %% [markdown]
# <h3>지도학습-회귀</h3>

# %% [markdown]
# ![image.png](attachment:48d1342f-8a25-4092-9d26-e04ef5324acc.png)

# %% [markdown]
# ![image.png](attachment:91493186-a13e-4400-8bb8-6bf94c53686e.png)

# %% [markdown]
# 레이블을 세번쨰 공간 차원(높이축)으로 취급했을 때, hyperplane(2차원이 아닌 다차원에서의 평면)을 데이터에 적합시킬 수 있다고 가정한다.
# 3차원 데이터를 관통하는 평면에 적합(fit)시키면 어떤 입력 매개변수에 대해서도 기대레이블을 예측할 수 있다는 말이 합리적으로 들린다.

# %% [markdown]
# <h3>비지도학습-군집화:레이블 없는 데이터에 대한 레이블 추론</h3>

# %% [markdown]
# ![image.png](attachment:7770075a-a687-4a28-b6e1-cf3aff19dd64.png)
# 군집화를 위한 예제 데이터

# %% [markdown]
# ![image.png](attachment:98c088fe-e941-4338-99cf-b17fec5b2356.png)
# k-평균 군집화 모델로 레이블을 할당한 데이터

# %% [markdown]
# k-평균은 k개의 군집중심으로 구성된 모델에 적합(fit)시킨다.

# %% [markdown]
# [머신러닝] K-평균(K-Means) 알고리즘
# https://velog.io/@jhlee508/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-K-%ED%8F%89%EA%B7%A0K-Means-%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98

# %% [markdown]
# K-means 알고리즘은 K-NN 알고리즘과 유사하면서도 다르다. 둘은 모두 K개의 점을 지정하여 거리를 기반으로 구현되는 거리기반 분석 알고리즘이다. 하지만 둘의 차이점은 지도학습에 속하는 K-NN 알고리즘과 달리 K-means 알고리즘은 비지도학습 방법에 속한다. 따라서 K-means 알고리즘의 목적을 분류(Classification)라고 하지 않고 군집화(Clustering)라고 한다. 즉, K-NN은 분류 알고리즘, K-means은 군집화 알고리즘이라고 할 수 있다.

# %% [markdown]
# We will discuss the *k*-means algorithm in more depth in [In Depth: K-Means Clustering](05.11-K-Means.ipynb).
# Other important clustering algorithms include Gaussian mixture models (See [In Depth: Gaussian Mixture Models](05.12-Gaussian-Mixtures.ipynb)) and spectral clustering (See [Scikit-Learn's clustering documentation](http://scikit-learn.org/stable/modules/clustering.html)).

# %% [markdown]
# <h3>비지도학습-차원축소:레이블 없는 데이터에 대한 구조 추론</h3>

# %% [markdown]
# [머신러닝]isomap 개념정리
# https://blog.naver.com/sw4r/221034788697

# %% [markdown]
# 3차원에서의 두 점사이의 거리와 2차원에서의 두 점 사이의 거리가 동일하다=>isomap

# %% [markdown]
# 일반적으로 차원의 개수는 줄이면서도 어떤식으로든 전체 데이터세트의 관련 품질을 보존하는 표현방식

# %% [markdown]
# ![image.png](attachment:c6b64d84-621b-40c6-9740-3d53298628e7.png)
# ![image.png](attachment:09d70ca2-9762-40e3-acd4-c32d423a014f.png)

# %% [markdown]
# feature1, feature2 일 때, 2차원이다.
# 100개나 1000개의 특징=>100개나 1000개의 차원=>100개나 1000개의 차원을 가진 데이터를 시각화하는 것은 어려운 일이고, 감당할 수 있는 수준으로 만드는 한 가지 방법은 데이터를 2차원이나 3차원으로 줄이는 차원 축소 기법을 사용하는것이다.

# %% [markdown]
# <h2>Scikit-Learn</h2><br />
# Scikit-Learn에서는 데이터를 DataFrame 관점으로 이해하는 것이 가장 좋다 <br />
# Scikit-Learn는 2차원형태여야 한다  [n_samples, n_features]

# %% [markdown]
# <h3>특징행렬 X</h3>
# [n_samples, n_features] <br />
# 표본(행)은 항상 데이터세트가 설명하는 개별 객체 <br />
# 특징(열)은 항상 각 표본을 정량적 방식으로 표현하는 개별 관측치 <br />

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=1.5);
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
"""특징행렬"""
X_iris = iris.drop('species', axis=1)
X_iris.shape
# Out:
# (150, 4)

# %%
"""대상행렬"""
y_iris = iris['species']
y_iris.shape
# Out:
# (150,)

# %% [markdown]
# ![image.png](attachment:7143eed8-f5ca-4ea4-91f2-d42252315700.png)

# %% [markdown]
# <h2>Estimator API</h2>

# %% [markdown]
# 1. Scikit-Learn 으로 적절한 Estimator 클래스를 임포트해서 모델의 클래스를 선택한다. <br />
# 2. 클래스를 원하는 값으로 인스턴스화해서 모델의 하이퍼파라미터 선택<br />
# 3. 데이터를 특징배열과 대상 벡터로 배치<br />
# 4. 모델 인스턴스의 fit()메서드를 호출해 모델을 데이터에 적합<br />
# 5. 모델을 새 데이터에 적용<br />
# -지도학습일 경우, predict() 사용해 알려지지 않은 데이터에 대한 레이블 예측<br />
# 비지도학습일 경우, transform()이나 predict() 사용해 데이터의 속성 변환하거나 추론한다.<br />

# %% [markdown]
# <h2>지도학습예제-간단한 선형회귀</h2>

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)
model
# Out:
# LinearRegression()

# %%
X = x[:, np.newaxis]
X.shape
# Out:
# (50, 1)

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
"""기울기"""
model.coef_
# Out:
# array([1.9776566])

# %%
"""절편"""
model.intercept_
# Out:
# -0.903310725531111

# %%
"""x값이 주어질 때, y값 예측"""
xfit = np.linspace(-1, 11)
Xfit = xfit[:, np.newaxis]
yfit = model.predict(Xfit)

# %%
plt.scatter(x, y)
plt.plot(xfit, yfit);

# %% [markdown]
# <h2>지도학습예제-붓꽃 분류-가우스 나이브 베이즈 모델 이용</h2>

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris,
                                                random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB # 1. choose model class
model = GaussianNB()                       # 2. instantiate model
model.fit(Xtrain, ytrain)                  # 3. fit model to data
y_model = model.predict(Xtest)             # 4. predict on new data

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)
# Out:
# 0.9736842105263158

# %% [markdown]
# <h2>비지도학습예제-붓꽃 차원-빠른 선형 차원 축소 기법인 주성분분석 사용<h2>

# %% [markdown]
# 붓꽃 데이터의 feature이 4개였다=>붓꽃데이터는 4차원이다.
# 비지도학습은 특징배열X만 가지고 한다.

# %% [markdown]
# 주성분분석 (PCA)를 통해 두 개의 성분, 즉 그 데이터의 2차원 표현을 반환하도록 요청한다.

# %%
from sklearn.decomposition import PCA  # 1. Choose the model class
model = PCA(n_components=2)            # 2. Instantiate the model with hyperparameters
model.fit(X_iris)                      # 3. Fit to data. Notice y is not specified!
X_2D = model.transform(X_iris)         # 4. Transform the data to two dimensions

# %%
iris['PCA1'] = X_2D[:, 0]
iris['PCA2'] = X_2D[:, 1]
sns.lmplot(x="PCA1", y="PCA2", hue='species', data=iris, fit_reg=False);

# %% [markdown]
# <h2> 비지도학습:차원축소</h2>

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
            transform=ax.transAxes, color='green')

# %%
X = digits.data
X.shape
# Out:
# (1797, 64)

# %%
y = digits.target
y.shape
# Out:
# (1797,)

# %%
from sklearn.manifold import Isomap
iso = Isomap(n_components=2)
iso.fit(digits.data)
data_projected = iso.transform(digits.data)
data_projected.shape
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_isomap.py:359: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\_index.py:108: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# (1797, 2)

# %%
plt.scatter(data_projected[:, 0], data_projected[:, 1], c=digits.target,
            edgecolor='none', alpha=0.5,
          )
plt.colorbar(label='digit label', ticks=range(10))
plt.clim(-0.5, 9.5);

# %% [markdown]
# <h2>베이즈 정리</h2>
# https://datascienceschool.net/02%20mathematics/06.06%20%EB%B2%A0%EC%9D%B4%EC%A6%88%20%EC%A0%95%EB%A6%AC.html

# %% [markdown]
# <h2>knn 알고리즘</h2>

# %% [markdown]
# ![image.png](attachment:9c2a2bfe-1f96-4381-bcd4-07c970b3d145.png)

# %% [markdown]
# <h2>초모수와 모델검증</h2>
# 1. 모델 클래스 선택 <br />
# 2. 모델 초모수 선택<br />
# 3. 모델을 훈련데이터에 적합( fit)<br />
# 4. 모델을 사용해 새 데이터에 대한 레이블 예측<br />

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target

# %%
print(type(X),X.shape,X.dtype)
# Out:
# <class 'numpy.ndarray'> (150, 4) float64

# %%
"""모델 클래스:KNeighborsClassifier"""
"""모델 초모수:k=1인 knn"""
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)

# %%
"""모델을 훈련데이터에 적합( fit) 및  예측"""
model.fit(X, y)
y_model = model.predict(X)

# %%
"""정확도 1.0은 모든점이 100%올바른 레이블 가지게 됨을 의미=>이 예제의 경우, train데이터와 test데이터가 동일하기에 근본적인 오류를 내포하고 있다."""
from sklearn.metrics import accuracy_score
accuracy_score(y, y_model)
# Out:
# 1.0

# %% [markdown]
# <h2>올바른 방식의 모델 검증</h2>
# 모델의 훈련 데이터에서 데이터의 일부를 빼내 그것을 모델 성능을 확인하는 검정표본(holdout set)으로 사용하는 것이다.

# %% [markdown]
# ![image.png](attachment:213a13bd-8c94-4a69-8d7e-0885137ff85a.png)

# %%
from sklearn.model_selection import train_test_split
# split the data with 50% in each set
X1, X2, y1, y2 = train_test_split(X, y, random_state=0,
                                  train_size=0.5)
"""X1,y1 :훈련데이터 """
"""X2,y2:검증데이터"""
# fit the model on one set of data
model.fit(X1, y1)

# evaluate the model on the second set of data
y2_model = model.predict(X2)
accuracy_score(y2, y2_model)
# Out:
# 0.9066666666666666

# %% [markdown]
# <h2>교차검증</h2>
# 검정표본을 사용할 떄 모델을 훈련시킬 데이터의 일부를 잃게 된다는 단점이 있다.
# 이 문제를 해결하는 한 가지 방법은 교차 검증을 사용하는 것이다.

# %% [markdown]
# ![image.png](attachment:c558e320-5d95-4dd0-ac1b-aa09564ddff6.png)

# %%
y2_model = model.fit(X1, y1).predict(X2)
y1_model = model.fit(X2, y2).predict(X1)
accuracy_score(y1, y1_model), accuracy_score(y2, y2_model)
# Out:
# (0.96, 0.9066666666666666)

# %%
"""k=1인 knn알고리즘+5겹 교차검증"""
from sklearn.model_selection import cross_val_score
cross_val_score(model, X, y, cv=5)
# Out:
# array([0.96666667, 0.96666667, 0.93333333, 0.93333333, 1.        ])

# %% [markdown]
# <h2>최적의 모델 선택하기 </h2>
# 더 복잡한 모델을 사용해서 결과가 악화되는 경우도 있고 더 많은 훈련 표본을 추가해도 결과가 개선되지 않을 수 있다. <br/>
# 어느 단계가 모델을 개선할 수 있을지 결정하는 능력이 중요하다

# %% [markdown]
# ![image.png](attachment:5c1f9e44-6912-4456-8fc3-67c078385176.png)

# %% [markdown]
# 과소적합<br />
# 직선을 가지고 데이터 분포 설명하려고 한다.  <br />
# 데이터가 직선보다 더 복잡하기 때문에 직선 모델은 결코 데이터세트를 제대로 설명할 수 없다.  <br />
# 데이터의 모든 특징을 적절히 설명할 만큼 모델 유연성이 충분하지 않다. <br />
#  <br />
# 과대적합<br />
# 고차다항식 그래프가 점들을 따라다닌다.<br />
# 데이터의세밀한 특징까지 거의 완벽히 설명할 수 있는 충분한 유연성을 가지고 있다.<br />
# 모델이 기본 데이터 분포와 함께 임의의 오류까지 설명할 정도로 너무 과한 모델 유연성을 가지고 있다.<br />
# 고분산이다.

# %% [markdown]
# <h2>R-squared</h2>
# https://velog.io/@yoonene/R-squared%EB%9E%80

# %% [markdown]
# ![image.png](attachment:170fcfae-ec73-4a5a-b3c0-5ae9ee861ac7.png)

# %% [markdown]
# ![image.png](attachment:6d431920-60c2-4f14-bee5-650994c93a0c.png)

# %% [markdown]
# SST=SSR+SSE <br />
# R=1일때 가장 좋다<br />
# SSR=0일 때, SSE=SST이고 R=1이다.가장 좋다<br />
# SSE=0일 때, SST=SSR이고 R=0이다.가장 안 좋다v

# %% [markdown]
# <h2>[Machine Learning] 손실 함수 (loss function)</h2>.
# https://insighted-h.tistory.com/7

# %% [markdown]
# ![image.png](attachment:656d26ce-fe14-4c2e-83e8-ceb0b803860b.png)

# %% [markdown]
# ![image.png](attachment:93ab0374-f646-4734-8cb9-329d76e5433c.png)

# %% [markdown]
# ![image.png](attachment:b159f50d-7f8d-4aa9-89aa-75c6291ce894.png)

# %% [markdown]
# <h2>scikit-learn 검증 곡선</h2>

# %%
"""클래스는 대문자로 시작/함수는 소문자로 시작"""
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
"""다항식 전처리 프로그램과 결합한 간단한 선형회귀로 구현=>가중치 구한다."""
def PolynomialRegression(degree=2, **kwargs):
    return make_pipeline(PolynomialFeatures(degree),
                         LinearRegression(**kwargs))

# %%
"""create some data"""
import numpy as np

def make_data(N, err=1.0, rseed=1):
    # randomly sample the data
    rng = np.random.RandomState(rseed)
    X = rng.rand(N, 1) ** 2
    y = 10 - 1. / (X.ravel() + 0.1)
    if err > 0:
        y += err * rng.randn(N)
    return X, y

X, y = make_data(40)

# %%
"""여러 차수의 다항식 적합(fit)을 시각화"""
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # plot formatting

X_test = np.linspace(-0.1, 1.1, 500)[:, None]

plt.scatter(X.ravel(), y, color='black')
axis = plt.axis()
for degree in [1, 3, 5]:
    y_test = PolynomialRegression(degree).fit(X, y).predict(X_test)
    plt.plot(X_test.ravel(), y_test, label='degree={0}'.format(degree))
plt.xlim(-0.1, 1.0)
plt.ylim(-2, 12)
plt.legend(loc='best');

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # plot formatting

X_test = np.linspace(-0.1, 1.1, 500)[:, None]

plt.scatter(X.ravel(), y, color='black')
axis = plt.axis()
for degree in [1, 10,20]:
    y_test = PolynomialRegression(degree).fit(X, y).predict(X_test)
    plt.plot(X_test.ravel(), y_test, label='degree={0}'.format(degree))
plt.xlim(-0.1, 1.0)
plt.ylim(-2, 12)
plt.legend(loc='best');

# %% [markdown]
# degree=1인 1차 방정식은 점과 예측값 사이의 오차가 크다. 과소적합에 가깝다. <br />
# degree=20인 20차 방정식은 점을 따라 선이 그려진다. 과대적합에 가깝다.

# %%
"""degree가 얼마일 때 좋은지 알아보기 위한 validation_curve함수를 통해 최적의 트레이드오프가 3차 다항식임을 알 수 있다. """
from sklearn.model_selection import validation_curve
degree = np.arange(0, 21)
train_score, val_score = validation_curve(PolynomialRegression(), X, y,param_name='polynomialfeatures__degree',param_range= degree, cv=7)

plt.plot(degree, np.median(train_score, 1), color='blue', label='training score')
plt.plot(degree, np.median(val_score, 1), color='red', label='validation score')
plt.legend(loc='best')
plt.ylim(0, 1)
plt.xlabel('degree')
plt.ylabel('score');

# %%
"""최적의 모델은 일반적으로 훈련 데이터의 규모에 의존한다."""
X2, y2 = make_data(200)
plt.scatter(X2.ravel(), y2);

# %%
"""학습곡선"""
degree = np.arange(21)
train_score2, val_score2 = validation_curve(PolynomialRegression(), X2, y2,
                                            param_name='polynomialfeatures__degree',param_range= degree, cv=7)

plt.plot(degree, np.median(train_score2, 1), color='blue', label='training score')
plt.plot(degree, np.median(val_score2, 1), color='red', label='validation score')
plt.plot(degree, np.median(train_score, 1), color='blue', alpha=0.3, linestyle='dashed')
plt.plot(degree, np.median(val_score, 1), color='red', alpha=0.3, linestyle='dashed')
plt.legend(loc='lower center')
plt.ylim(0, 1)
plt.xlabel('degree')
plt.ylabel('score');

# %% [markdown]
# 실선은 5배 더 많은 점으로 나온 결과이다. <br />
# 더 연한 색의 점선은 이전의 더 작은 데이터세트에 대한 결과이다.

# %% [markdown]
# 검증곡선의 행동은 모델 복잡도와 훈련 데이터 점의 개수에 의해 결정된다.

# %%
from sklearn.model_selection  import learning_curve

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

for i, degree in enumerate([2, 9]):
    N, train_lc, val_lc = learning_curve(PolynomialRegression(degree),
                                         X, y, cv=7,
                                         train_sizes=np.linspace(0.3, 1, 25))

    ax[i].plot(N, np.mean(train_lc, 1), color='blue', label='training score')
    ax[i].plot(N, np.mean(val_lc, 1), color='red', label='validation score')
    ax[i].hlines(np.mean([train_lc[-1], val_lc[-1]]), N[0], N[-1],
                 color='gray', linestyle='dashed')

    ax[i].set_ylim(0, 1)
    ax[i].set_xlim(N[0], N[-1])
    ax[i].set_xlabel('training size')
    ax[i].set_ylabel('score')
    ax[i].set_title('degree = {0}'.format(degree), size=14)
    ax[i].legend(loc='best')

# %% [markdown]
# 학습곡선이 이미 수렴한 경우라면, 훈련데이터를 더 많이 추가한다고 해서 적합도가 눈에 띄게 개선되지 않을 것이다. <br />
# 수렴된 점수를 증가시키는 유일한 방법은 일반적으로 더 복잡한 모델을 사용하는 것이다.<br/>
# 좀 더 복잡한 모델로 옮겨가면 수렴점수는 높아지지만 훈련점수와 검증점수 사이의 차이가 높아지는 것을 감수해야 한다.<br/>
# 훨씬 더 많은데이터 점을 추가하면 더욱 복잡한 모델의 학습곡선도 결국에는 수렴하게 된다.

# %% [markdown]
# <h2>실제 검증:그리드 검색</h2>

# %%
"""최적의 다항식 모델을 구하기 위해 그리드 검색 사용하는 예제"""
from sklearn.model_selection import GridSearchCV

param_grid = {'polynomialfeatures__degree': np.arange(21),
              'linearregression__fit_intercept': [True, False]
             }
grid = GridSearchCV(PolynomialRegression(), param_grid, cv=7)

# %%
grid.fit(X, y);

# %%
grid.best_params_
# Out:
# {'linearregression__fit_intercept': False, 'polynomialfeatures__degree': 4}

# %%
model = grid.best_estimator_

plt.scatter(X.ravel(), y)
lim = plt.axis()
y_test = model.fit(X, y).predict(X_test)
plt.plot(X_test.ravel(), y_test);
plt.axis(lim);

# %% [markdown]
# <h2>특징공학</h2>
# 문제에 대해 가지고 있는 정보를 모두 취해 특징행렬을 구축하는 데 사용할 수 있는 숫자로 변환하는 것

# %% [markdown]
# <h3>1) 범주(카테고리) 특징</h3>
# -원-핫 인코딩 <br />
# -DictVectorizer

# %%
data = [
    {'price': 850000, 'rooms': 4, 'neighborhood': 'Queen Anne'},
    {'price': 700000, 'rooms': 3, 'neighborhood': 'Fremont'},
    {'price': 650000, 'rooms': 3, 'neighborhood': 'Wallingford'},
    {'price': 600000, 'rooms': 2, 'neighborhood': 'Fremont'}
]

# %%
"""원-핫 인코딩"""
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer(sparse=False, dtype=int)
vec.fit_transform(data)
# Out:
# array([[     0,      1,      0, 850000,      4],
#        [     1,      0,      0, 700000,      3],
#        [     0,      0,      1, 650000,      3],
#        [     1,      0,      0, 600000,      2]])

# %%
vec.get_feature_names_out()
# Out:
# array(['neighborhood=Fremont', 'neighborhood=Queen Anne',
#        'neighborhood=Wallingford', 'price', 'rooms'], dtype=object)

# %% [markdown]
# <h3>2) 텍스트 특징</h3>
# -word count 단어 세기 <br />
# -CountVectorizer

# %%
sample = ['problem of evil',
          'evil queen',
          'horizon problem problem']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer()
X = vec.fit_transform(sample)
X
# Out:
# <3x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
import pandas as pd
pd.DataFrame(X.toarray(), columns=vec.get_feature_names_out())
# Out:
#    evil  horizon  of  problem  queen
# 0     1        0   1        1      0
# 1     1        0   0        0      1
# 2     0        1   0        2      0

# %% [markdown]
# <h3>[NLP] TF-IDF 설명 | 텍스트 데이터 통계적 가중치 계산 | 특정 단어가 문서 내에서 얼마나 중요한지</h3>
# https://mvje.tistory.com/174

# %% [markdown]
# ![image.png](attachment:2edef69f-a48c-41b2-9aab-f4e61113541e.png)

# %% [markdown]
# ![image.png](attachment:f109dc04-b148-4cef-a001-5d61818d1f90.png)

# %% [markdown]
# <h3>선형 회귀 - 선형 기저 함수 모델</h3>
# https://mldiary.tistory.com/55

# %% [markdown]
# ![image.png](attachment:5881c866-a918-4b5b-9a13-16de1021fab2.png)

# %% [markdown]
# ![image.png](attachment:a6bc79dc-9a22-4d6e-a647-42e5f5974bae.png)

# %% [markdown]
# ![image.png](attachment:9549c772-ee91-4c75-b513-46ab5f201db1.png)
# ![image.png](attachment:4e0ede50-1a1e-4913-9fe9-424286a04ff2.png)
# ![image.png](attachment:f22ccb3b-57b6-4f8e-8f59-258bd86b7a9d.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5])
y = np.array([4, 2, 1, 3, 7])
plt.scatter(x, y);

# %%
"""1차방정식이라서 오차가 많이 나서 좋지 않다.=>x,y 사이의 관계를 설명하기 위해 더 복잡한 모델이 분명히 필요하다"""
from sklearn.linear_model import LinearRegression
X = x[:, np.newaxis]
model = LinearRegression().fit(X, y)
yfit = model.predict(X)
plt.scatter(x, y)
plt.plot(x, yfit);

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=False)
X2 = poly.fit_transform(X)
print(X2)
# Out:
# [[  1.   1.   1.]
#  [  2.   4.   8.]
#  [  3.   9.  27.]
#  [  4.  16.  64.]
#  [  5.  25. 125.]]

# %%
model = LinearRegression().fit(X2, y)
yfit = model.predict(X2)
plt.scatter(x, y)
plt.plot(x, yfit);

# %% [markdown]
# ![image.png](attachment:5c36b262-8972-4157-abb6-9473da91e49e.png)

# %% [markdown]
# 모델을 바꾸지 않고 입력값을 변환해서 모델을 개선한다는 개념은 수많은 더 강력한 머신러닝 방식에서는 기본이다.
# 커널법

# %% [markdown]
# <h3>누락데이터의 대체</h3>
# 1)간단한 방법(예:평균,중앙값, 최빈값)<br />
# 2)정교한 방법(예:행렬 완성이나 그러한 데이터를 처리하는 견고한 모델 사용)

# %%
from numpy import nan
X = np.array([[ nan, 0,   3  ],
              [ 3,   7,   9  ],
              [ 3,   5,   2  ],
              [ 4,   nan, 6  ],
              [ 8,   8,   1  ]])
y = np.array([14, 16, -1,  8, -5])

# %%
"""누락된 값이 해당 열의 나머지 값들의 평균으로 대체됐다."""
from sklearn.impute import SimpleImputer
imp =SimpleImputer(strategy='mean')
X2 = imp.fit_transform(X)
X2
# Out:
# array([[4.5, 0. , 3. ],
#        [3. , 7. , 9. ],
#        [3. , 5. , 2. ],
#        [4. , 5. , 6. ],
#        [8. , 8. , 1. ]])

# %% [markdown]
# <h3>특징 파이프라인</h3>
# 여러 단계를 하나로 묶음 <br />
# 1. 누락된 값을 평균으로 대체 <br />
# 2. 특징을 이차 형태로 전환 <br />
# 3. 선형회귀 적합

# %%
from sklearn.pipeline import make_pipeline

model = make_pipeline(SimpleImputer(strategy='mean'),
                      PolynomialFeatures(degree=2),
                      LinearRegression())

# %%
model.fit(X, y)  # X with missing values, from above
print(y)
print(model.predict(X))
# Out:
# [14 16 -1  8 -5]
# [14. 16. -1.  8. -5.]

# %% [markdown]
# <h3>심화학습 :나이브 베이즈 분류</h3>
# https://m.blog.naver.com/arceus2/222072830355

# %% [markdown]
# ![image.png](attachment:0e6e56d1-d392-488a-93ed-b7657dba741a.png)
# ![image.png](attachment:5104ca9c-6dd8-42de-9c81-f3dc626f56d4.png)
